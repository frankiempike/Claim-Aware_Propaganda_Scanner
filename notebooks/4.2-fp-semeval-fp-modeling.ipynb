# %% [markdown]
# This notebook is for modeling and evaluating technique classification from the SemEval dataset

# %%
import pandas as pd
import numpy as np
import torch
from pathlib import Path
from transformers import AutoTokenizer, AutoModelForTokenClassification, TrainingArguments, Trainer, DataCollatorForTokenClassification
from datasets import Dataset
import evaluate

# %%
#Set up paths
BASE_DIR = Path("..")
DATA_DIR = BASE_DIR / "data" / "processed"
MODEL_DIR = BASE_DIR / "models" / "semeval_bert_scanner"

# %%
#Load technique classification data
df_tc = pd.read_csv(DATA_DIR / "semeval_tc_cleaned.csv")
df_tc.head()
# Out:
#    article_id                  technique  start_char  end_char  \
# 0   758756657                 Repetition        5024      5036
# 1   758756657                 Repetition        5302      5314
# 2   758756657            Loaded_Language          62        69
# 3   758756657  Causal_Oversimplification         606       746
# 4   758756657            Loaded_Language        4352      4361
#
#                         source_file  \
# 0  article758756657.task2-TC.labels
# 1  article758756657.task2-TC.labels
# 2  article758756657.task2-TC.labels
# 3  article758756657.task2-TC.labels
# 4  article758756657.task2-TC.labels
#
#                                         text_content  \
# 0  Islamizing the Schools: The Case of West Virgi...
# 1  Islamizing the Schools: The Case of West Virgi...
# 2  Islamizing the Schools: The Case of West Virgi...
# 3  Islamizing the Schools: The Case of West Virgi...
# 4  Islamizing the Schools: The Case of West Virgi...
#
#               technique_list  \
# 0                 Repetition
# 1                 Repetition
# 2            Loaded_Language
# 3  Causal_Oversimplification
# 4            Loaded_Language
#
#                                            span_text  sentiment  punct_count  \
# 0                                       Islamization   0.000000            0
# 1                                       Islamization   0.000000            0
# 2                                            outrage   0.000000            0
# 3  In order to convert to Islam, one says the sha...  -0.166667            0
# 4                                          egregious   0.000000            0
#
#    lexical_diversity
# 0           1.000000
# 1           1.000000
# 2           1.000000
# 3           0.785714
# 4           1.000000
